# %%
import collections
import os

# %%
from collections import Counter

# %%
directory = '/Users/adyasingh/Desktop/Semantic-Search-Engine/text_files/txt'
data = []
# data_str = ""

# %%
for file in os.listdir(directory):
#     print(file)
    f = open(os.path.join(directory, file), "r", encoding="utf8")
    fileContent = f.read()
    data.append(fileContent.lower())
    f.close()

# %%
data_str = ''.join(data)
data_str = data_str.lower()
split_it = data_str.split()

# %%
  
# Pass the split_it list to instance of Counter class. 
Counter = Counter(split_it)

# %%
  
# most_common() produces k frequently encountered 
# input values and their respective counts. 
most_occur = Counter.most_common(3000) 
  
print(most_occur)
# Out:
# [('.', 3513120), ('the', 2586699), ('of', 1960311), ('and', 1746884), ('to', 1225626), ('in', 1040113), ('our', 611465), ('a', 589027), ('for', 517938), ('or', 423252), ('as', 415557), ('on', 397048), ('we', 346582), ('is', 307979), ('are', 290650), ('with', 277273), ('that', 275982), ('by', 273669), ('$', 272408), ('be', 218875), ('financial', 215907), ('from', 211179), ('other', 195768), ('—', 190975), ('company', 185131), ('at', 181255), ('31,', 162277), ('which', 159042), ('not', 157566), ('an', 154364), ('million', 152845), ('may', 148632), ('stock', 148011), ('december', 145953), ('have', 143593), ('income', 138781), ('net', 134962), ('tax', 132452), ('this', 131814), ('any', 121885), ('cash', 121858), ('these', 115582), ('such', 113620), ('was', 109191), ('its', 108224), ('under', 108075), ('value', 104480), ('year', 103949), ('?', 102317), ('assets', 101282), ('will', 96444), ('shares', 94367), ('consolidated', 93349), ('revenue', 91579), ('ended', 89002), ('operating', 88452), ('business', 85134), ('related', 83499), ('all', 83270), ('total', 83111), ('services', 81796), ('has', 80795), ('statements', 80397), ('common', 79298), ('products', 77928), ('if', 76906), ('company’s', 76711), ('�', 75256), ('fiscal', 74888), ('market', 73329), ('fair', 73273), ('were', 73162), ('new', 71496), ('during', 71406), ('•', 71207), ('-', 70892), ('over', 70817), ('could', 69882), ('sales', 69600), ('certain', 67711), ('based', 67159), ('interest', 66835), ('including', 64249), ('–', 64232), ('also', 61150), ('their', 60772), ('operations', 59908), ('costs', 59384), ('accounting', 58995), ('information', 58855), ('share', 58509), ('results', 58441), ('report', 58326), ('years', 58103), ('it', 57977), ('annual', 57300), ('future', 56717), ('been', 55396), ('per', 55082), ('inc.', 54739), ('amount', 54047), ('customers', 53736), ('period', 53246), ('cost', 53195), ('march', 52983), ('rate', 52965), ('foreign', 52698), ('due', 52515), ('compensation', 52509), ('each', 52365), ('than', 52271), ('product', 51775), ('plan', 51739), ('increase', 51703), ('no', 51576), ('software', 51344), ('u.s.', 51328), ('price', 50345), ('service', 50252), ('exchange', 50163), ('management', 49909), ('deferred', 49448), ('current', 49020), ('securities', 48924), ('significant', 48772), ('customer', 48549), ('executive', 48530), ('board', 48200), ('notes', 47817), ('equity', 47163), ('form', 46907), ('more', 45849), ('us', 45818), ('e', 45264), ('changes', 45050), ('into', 45047), ('item', 44631), ('expense', 44219), ('credit', 44111), ('purchase', 43571), ('development', 43384), ('date', 43325), ('reporting', 42765), ('loss', 42699), ('liabilities', 42551), ('through', 42276), ('approximately', 42261), ('expenses', 42226), ('number', 42098), ('data', 41495), ('subject', 41272), ('performance', 41201), ('result', 41143), ('capital', 41001), ('agreement', 40934), ('revenues', 40726), ('primarily', 40650), ('technology', 40244), ('following', 39608), ('included', 39595), ('control', 39005), ('internal', 38803), ('options', 38695), ('n', 38439), ('additional', 38370), ('million,', 38142), ('time', 38095), ('january', 37679), ('material', 37345), ('required', 37171), ('��', 36754), ('upon', 36707), ('1', 36421), ('use', 35840), ('balance', 35830), ('used', 35542), ('directors', 34772), ('provide', 34537), ('increased', 34300), ('statement', 33745), ('recorded', 33187), ('outstanding', 33003), ('note', 32992), ('2014', 32989), ('quarter', 32970), ('change', 32934), ('option', 32655), ('expected', 32588), ('impact', 32552), ('shall', 32546), ('recognized', 32536), ('2015', 32285), ('table', 32174), ('o', 31987), ('those', 31968), ('one', 31583), ('amounts', 31519), ('section', 31497), ('part', 31490), ('investments', 31476), ('2016', 31452), ('prior', 31385), ('2013', 31370), ('can', 30892), ('investment', 30818), ('systems', 30778), ('filed', 30680), ('issued', 30565), ('would', 30487), ('r', 30476), ('no.', 30407), ('equipment', 30155), ('(in', 30109), ('grou ...

# %%
popular_words = open("popular_words.txt","w+")

# %%
for word in most_occur: 
#     popular(word[0])
    popular_words.write(word[0]+"\n")
popular_words.close()

# %%
bert_vocab = open('bert_vocab.txt').readlines()
with open('result.txt', 'w') as result:
    for line in open('popular_words.txt'):
        if line not in bert_vocab and (line not in added) and ('�' not in line) :
            result.write(line)

# %%
# Out:
# —
#
# 31,
#
# company’s
#
# •
#
# –
#
# inc.
#
# u.s.
#
# deferred
#
# liabilities
#
# million,
#
# no.
#
# (in
#
# 1,
#
# 30,
#
# long-term
#
# intangible
#
# addition,
