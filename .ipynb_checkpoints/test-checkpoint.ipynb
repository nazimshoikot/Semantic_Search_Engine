# %%
from sentence_transformers import SentenceTransformer, models, InputExample, losses

# %%
model = SentenceTransformer('bert-large-nli-mean-tokens')

# %%
word_embedding_model = model._first_module()

# tokens = ["money", "business"]

# %%
tokens = []
for line in open('result.txt'):
    tokens.append(line)

# %%
word_embedding_model.tokenizer.add_tokens(tokens, special_tokens=True)
word_embedding_model.auto_model.resize_token_embeddings(len(word_embedding_model.tokenizer))
# Out:
# Embedding(31371, 1024)

# %%
word_embedding_model.train()
# Out:
# Transformer(
#   (auto_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31371, 1024)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
# ...

# %%
word_embedding_model.eval()
# Out:
# Transformer(
#   (auto_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31371, 1024)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
# ...

# %%
from torch.utils.data import DataLoader
import os
import re

# %%
model2 = SentenceTransformer('bert-large-nli-mean-tokens')

# %%
directory = '/Users/adyasingh/Desktop/Semantic-Search-Engine/text_files/txt'
data = []

# %%
for file in os.listdir(directory):
#     print(file)
    f = open(os.path.join(directory, file), "r", encoding="utf8")
    fileContent = f.read()
    sentences = re.split(r' *[\.\?!][\'"\)\]]* *', fileContent)
    for s in sentences: 
        data.append(s.lower())

#     data.append(fileContent.lower())
    f.close()
